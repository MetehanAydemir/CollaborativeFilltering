# %%
import pandas as pd 


animesynopsis=pd.read_csv('./data/anime_with_synopsis.csv')
animelist=pd.read_csv('./data/animelist.csv')
rating_complete=pd.read_csv('./data/rating_complete.csv')
anime=pd.read_csv('./data/anime.csv')

# %%
anime=pd.read_csv('./data/anime.csv')
anime
# Out:
#        anime_id                             Name    Score  \
# 0             1                     Cowboy Bebop     8.78
# 1             5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2             6                           Trigun     8.24
# 3             7               Witch Hunter Robin     7.27
# 4             8                   Bouken Ou Beet     6.98
# ...         ...                              ...      ...
# 17557     48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 17558     48483                     Mieruko-chan  Unknown
# 17559     48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 17560     48491      Yama no Susume: Next Summit  Unknown
# 17561     48492                    Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# ...

# %%
animest=pd.DataFrame(anime, columns=['anime_id', 'Name', 'Score'])
animest
# Out:
#        anime_id                             Name    Score
# 0             1                     Cowboy Bebop     8.78
# 1             5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2             6                           Trigun     8.24
# 3             7               Witch Hunter Robin     7.27
# 4             8                   Bouken Ou Beet     6.98
# ...         ...                              ...      ...
# 17557     48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 17558     48483                     Mieruko-chan  Unknown
# 17559     48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 17560     48491      Yama no Susume: Next Summit  Unknown
# 17561     48492                    Scarlet Nexus  Unknown
#
# [17562 rows x 3 columns]

# %%
rating_complete
# Out:
#           user_id  anime_id  rating
# 0               0       430       9
# 1               0      1004       5
# 2               0      3010       7
# 3               0       570       7
# 4               0      2762       9
# ...           ...       ...     ...
# 57633273   353404       502       8
# 57633274   353404       987       4
# 57633275   353404       225       8
# 57633276   353404       243       7
# 57633277   353404       896       7
#
# [57633278 rows x 3 columns]

# %%
ratings=pd.merge(animest,rating_complete)

# %%
ratings.head(20)
# Out:
#     anime_id          Name Score  user_id  rating
# 0          1  Cowboy Bebop  8.78        3       9
# 1          1  Cowboy Bebop  8.78        6       6
# 2          1  Cowboy Bebop  8.78       14       9
# 3          1  Cowboy Bebop  8.78       19       8
# 4          1  Cowboy Bebop  8.78       22       9
# 5          1  Cowboy Bebop  8.78       23       9
# 6          1  Cowboy Bebop  8.78       44       9
# 7          1  Cowboy Bebop  8.78       53      10
# 8          1  Cowboy Bebop  8.78       57       9
# 9          1  Cowboy Bebop  8.78       62      10
# 10         1  Cowboy Bebop  8.78       65      10
# 11         1  Cowboy Bebop  8.78       73       9
# 12         1  Cowboy Bebop  8.78       77       7
# 13         1  Cowboy Bebop  8.78       85       9
# 14         1  Cowboy Bebop  8.78       89      10
# 15         1  Cowboy Bebop  8.78       94       9
# 16         1  Cowboy Bebop  8.78      108      10
# 17         1  Cowboy Bebop  8.78      112      10
# ...
